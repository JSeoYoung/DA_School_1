# %% [markdown]
# # 주석

# %%
# 주석: 코드를 보류하거나
# 해당 코드에 대한 설명을 할 경우

# 행 단위 주석입니다.

# 열
# 단위
# 주석입니다.

'''
열
단위
주석입니다.
'''

1+1
# Out:
# 2

# %%
def solution(hello):
    """Connects to the next available port.

    Args:
      minimum: A port value greater or equal to 1024.

    Returns:
      The new minimum port.

    Raises:
      ConnectionError: If no available port is found.
    """
    return hello

# """ """ 함수 안에 쓰는 이유
# : solution 입력하면 주석이 같이 보임 (마우스를 solution위에 갖다대면)

# %%
solution('hello')
# Out:
# 'hello'

# %%
# 주석을 읽지 않고도 쉽게 읽을 수 있는 코드

# %% [markdown]
# # 변수

# %% [markdown]
# ## CS(Computer Science)에서 변수란? 포스트잇(메모리 공간을 가리키는)

# %%
a = 10 # a -> 10
a = 20 # a -> 20

# %% [markdown]
# EX 1) ???? 왜 다르지??

# %%
a = 10
b = a
a = 20
b
# Out:
# 10

# %%
id(a)
# Out:
# 140379946253200

# %%
id(b)
# Out:
# 140379946252880

# %% [markdown]
# EX 2) 값: 10 -> 같음

# %%
a = 10
b = a

# %%
id(a), id(b)
# Out:
# (140379946252880, 140379946252880)

# %%
a is b
# Out:
# True

# %% [markdown]
# EX 3) 값: 257 -> 다름

# %%
a = 10
b = 10

# %%
id(a), id(b)
# Out:
# (140379946252880, 140379946252880)

# %%
a = 257
b = 257

# %%
id(a), id(b)
# Out:
# (140378681651280, 140378681652080)

# %%
a is b
# Out:
# False

# %% [markdown]
# Python은 자체적으로 속도를 높이기 위한 여러가지 노력들을 해왔습니다.
# 그래서 **0 ~ 256은 먼저 메모리에 적재**를 합니다.

# %% [markdown]
# ## 변수의 속성
#
# * 영문과 숫자를 사용할 수 있지만, 숫자로 시작하지는 못합니다.
# * 특수문자는 사용하지 않아요(언더바(_)는 사용합니다. 스네이크 표기법, 특수문자나 이미 사용 가능한 것들이 있기는 합니다. 권하지 않습니다.)
# * 예약어는 사용하지 않습니다.(if, elif, while, for, etc)
# * 대소문자는 구분합니다.
# * 언더바로만 사용하거나 언더바로 시작할 수 있습니다.
# * 대문자로 시작하는 변수를 사용할 수 있지만, 관습적으로 대문자로 시작하는 변수는 Class로 만들기 때문에 소문자로 시작하는 변수를 만들기를 권합니다.Class는 보통 파스칼 표기법을 따릅니다. 다만 회사 컨벤션마다 다릅니다.

# %%
hello_world = 10 # 스네이크 표기법은 컨벤션으로 있는 경우가 많습니다.
helloWorld = 10 # 카멜 표기법: JavaScript에서 많이 사용
hello1 = 100
# 1hello = 100 # error
# π = 3.14 # error가 안나지만 사회생활 힘듭니다.
# π * 100

_ = 100 # 권장하지 않습니다.

# 아래와 같이 반복 안에서 전혀 사용하지 않는 경우
# (관습적으로) 많이 사용됩니다.
for _ in range(10):
  print('hello')
  print(____ + ____)

# %% [markdown]
# ## 변수의 Type

# %% [markdown]
# * 변수의 타입은 왜 있는 것일까?
#     * 효율적인 측면
#     * 관리적인 측면
#
# * 숫자 자료형
#
# ![image.png](data:image/png;base64,...)
#
# * 시퀀스 자료형
#     * 각 요소들은 해당하는 Index 값을 가짐
#     * 문자열, 리스트, 튜플이 해당
#     * 딕셔너리랑 셋은 포함X

# %%
'a' + 'a'

# 왜 이어 붙였는가?

# 우리가 통념적으로 생각하는 문자열의 연산을 Python이라는 언어에 구현해놓은 것입니다.
# 메직 메서드(__init__, ...)를 통해서 이런 '약속'들을 구현하게 됩니다.
# Out:
# 'aa'

# %%
def hello():
  return

Class A:
  pass

a = 10     #int, 정수형
b = 10.1   #float, 실수
c = -1
d = True   #bool, 논리형(부울형, 참거짓형)
e = 'good'
f = '10'   #str, 문자열
g = 'kim'
h = 'honggildong'
i = 'example'
j = 10 + 2j #complex, 복소수
k = 0b110   #int, 2진법 
l = 0o56    #int, 8진법
m = 0xAC    #int, 16진법

######추가사항######
n = hello  #function
o = print  #built-in function
p = lambda x:x**2  #function
q = A  #class
r = A()  #instance
############

print('type(10) : ', type(a))
print('type(10.1) : ', type(b))
print('type(-1) : ', type(c))
print('type(True) : ', type(d))
print('type(\'good\') : ', type(e))
print('\'10\' + \'10\' : ', f + f)
print('\'10\' * 3', f * 3)
print('\'hong\' + \'gildong\'', g + h)
print('type(\'gildong\') : ', type(h))
print('type(\'gildong100!!\') : ', type(i))
print('type(10 + 2j) : ', type(j))
print('type(0b110) : ', type(k))
print(k)
print('type(0o56) : ', type(i))
print(i)
print('type(0xAC) : ', type(m))
print(m)

# %% [markdown]
# ### int(정수)

# %%
# 10, -10

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
#  'as_integer_ratio',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %% [markdown]
# * **진법**

# %%
a = 0b110   #int, 2진법, 0과 1 (숫자를 2개만 쓰는 것입니다.)
b = 0o56    #int, 8진법, 0 ~ 7 (숫자를 8개만 쓰는 것입니다.)
c = 0xAD    #int, 16진법, 0 ~ 9, A ~ F (숫자를 10개만 쓰는 것입니다.)

type(a), type(b), type(c)
# Out:
# (int, int, int)

# %%
a, b, c
# Out:
# (6, 46, 173)

# %%
bin(6), oct(46), hex(172)
# Out:
# ('0b110', '0o56', '0xac')

# %%
# 모든 언어 공통(2진법으로 변환했을 때 무한대수가 발생됩니다.)
# 부동 소수점 오차 발생

0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
a = 10
type(a)
# Out:
# int

# %%
'100' + '100'
# Out:
# '100100'

# %% [markdown]
# * 형변환

# %%
int('100') + int('100') # 형 변환
# Out:
# 200

# %%
int('0b110', 2), int('0o56', 8), int('0xac', 16)
# Out:
# (6, 46, 172)

# %%
int('110', 2), int('56', 8), int('ac', 16)
# Out:
# (6, 46, 172)

# %%
int('10') + int('10')
# Out:
# 20

# %%
# 참고
class int(int):
  def __add__(self, a):
    return self * a

int('10') + int('10')
# Out:
# 100

# %% [markdown]
# ### float(실수)

# %%
a = 10.1

type(a)

# %%
dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setformat__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %%
type(10 + 10.1)  # 다른 언어는 error...
# Out:
# float

# %% [markdown]
# ### str(문자열)
#
# * 왜 문자'형'이 아니라 문자'열'일까요?

# %% [markdown]
# * 순서가 있습니다.
# * 순회가 가능합니다.

# %%
a = 'Hello World'

type(a)
# Out:
# str

# %%
b = 'paullab CEO leehojun'

b[0] # 대괄호 안에 들어간 값을 index라고 하고, 이렇게 index로 값을 호출하는 방법을 indexing이라고 합니다.
b[1]

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
# 'Ctrl' + 'Alt' + 화살표위아래 : 글의 열 선택
#  -> 'Delete' : 글의 선택된 열이 하나씩 삭제됨

'capitalize','casefold','center','count','encode','endswith','expandtabs',
'find','format','format_map','index','isalnum','isalpha','isascii','isdecimal',
'isdigit','isidentifier','islower','isnumeric','isprintable','isspace','istitle',
'isupper','join','ljust','lower','lstrip','maketrans','partition','removeprefix',
'removesuffix','replace','rfind','rindex','rjust','rpartition','rsplit','rstrip',
'split','splitlines','startswith','strip','swapcase','title','translate','upper','zfill'

# %% [markdown]
# * 모든 Line은 79자 (Characters)로 제한하시기를 권도합니다.

# %%
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa => 80자
# 아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아 => 42자면 한글 넘어갑니다.
# line에 딱 맞춰 들어간 것을 볼 수 있습니다.
# 강제사항은 아닙니다.
# 띄어쓰기 4번도 강제사항은 아닙니다.
# pep8에 기술되어 있습니다. => PEP(Python Enhancement Proposal)란 무엇인가요? 8이란 무엇인가요?
# pep8 : Style Guide for Python Code
# pep20 : The Zen of Python

# %%
for i in range(10):
          print(i)
          print(i + i)

# %%
a
# Out:
# 'Hello World'

# %%
a.lower()
# Out:
# 'hello world'

# %%
a.upper()
# Out:
# 'HELLO WORLD'

# %%
a.islower()
# Out:
# False

# %%
'hello'.islower() # 전부다 소문자로 이뤄져 있는가?
# Out:
# True

# %%
'hello'.isupper() # 전부다 대문자로 이뤄져 있는가?
# Out:
# False

# %%
'HELLO'.isupper()
# Out:
# True

# %%
'123'.isdigit() # 숫자인가?
# Out:
# True

# %%
'123'.isalpha()
# Out:
# False

# %%
# 아래 문자열 중 숫자만 다 더해라
s = 0
for i in '123abc7584739203lsdlfei123ndsdf':
    if i.isdigit():
      s += int(i)
s
# Out:
# 60

# %%
' '.isalpha()
# Out:
# False

# %%
'hello world'.isalpha()
# Out:
# False

# %%
'hello world'.count('l')
# Out:
# 3

# %%
'capitalize','casefold','center','count','encode','endswith','expandtabs',
'find','format','format_map','join','ljust','lower','lstrip',
'maketrans','partition','removeprefix',
'removesuffix','replace','rfind','rindex','rjust','rpartition','rsplit','rstrip',
'split','splitlines','startswith','strip','swapcase','title','translate','upper','zfill'

# %%
# 1부터 10000까지 8개 갯수를 모두 세어라.
'[1,2,3,4,5]'.count(',')
str(list(range(10000))).count('8')
# Out:
# 4000

# %%
'leehojun'.center(10)
'leehojun'.center(20)
'leehojun'.center(10,'!')
'leehojun'.center(20,'-')

'paullab CEO leehojun'.rjust(30) # 오른쪽 정렬
'paullab CEO leehojun'.ljust(30) # 왼쪽 정렬
'paullab CEO leehojun'.center(30) # 가운데 정렬
# Out:
# '------leehojun------'

# %%
'leehojun'.index('e')
# 'leehojun'.index('z')  # 못찾으면 error
# Out:
# 1

# %%
'leehojun'.find('h')
# 'leehojun'.index('z')  # 못찾으면 -1
# Out:
# 3

# %%
# 그러면 어떤 코드가 더 좋은가요?
# 정답은 없습니다.

# %%
'hello'.count('') # ??
# Out:
# 6

# %%
a = ''

'hello'.count(a)
# Out:
# 6

# %%
# https://stackoverflow.com/questions/40192449/why-are-str-count-and-lenstr-giving-different-output
a = ''
print(len(a))
print(a.count(''))
# ' t e s t ' => 빈 문자가 5번 카운팅

# %%
# 중요하진 않습니다.
'paullab CEO leehojun.'.endswith('.') # 마침표로 끝났느냐?
# Out:
# True

# %%
'paullab CEO leehojun.'.endswith('!') # 느낌표로 끝났느냐?
# Out:
# False

# %%
'paullab CEO leehojun.'[-1] == '.'
'paullab CEO leehojun.'[-1] == '!'
# Out:
# False

# %%
''.join(['hello', 'world', 'hojun'])
'!'.join(['hello', 'world', 'hojun'])
'-'.join(['010', '5044', '2903'])
# '-'.join([010, 5044, 2903]) # join하려면 string 형이어야 한다.
# Out:
# '010-5044-2903'

# %%
# %용법이 최초에 있었습니다. 안써요. 기억하시지 않으셔도 됩니다.
name = 'hojun'
age = 11
print(r'%', '용법: name %s'%name)
print(r'%', '용법: name %s age %d'%(name, age))
# Out:
# % 용법: name hojun
# % 용법: name hojun age 11

# %%
# format 용법이 생겼습니다.
# format 용법만 별도 정리 해드리겠습니다. (1시간 정도)
name = 'hojun'
age = 11
txt = 'name {} age {}'
print('name {} age {}'.format(name, age))
print('name {0} age {1}'.format(name, age))
print('name {1} age {1}'.format(name, age))
print(txt.format(name, age))

# %%
# f-string 용법이 생겼습니다.(3.6 version에서 새로 나옴)
name = 'hojun'
age = 11
print(f'name: {name} age: {age}')

# %%
'hello world'.find('l')
'hello world'.rfind('l')
'hello world'.rindex('l')
# Out:
# 9

# %%
'              hello world                        '.strip() # rstrip, lstrip
# Out:
# 'hello world'

# %%
'100'.zfill(10) # 10자리를 채웁니다.
# '1000000000'.zfill(9) # 주어진 자리수는 다 표시됨
# Out:
# '1000000000'

# %%
# 문자열 자르기
'010-0000-0000'.split('-')
'010-00!00-00!00'.split('!')
# Out:
# ['010-00', '00-00', '00']

# %%
'paullab CEO leehojun'.replace('CEO', 'CTO').replace('hojun', 'gildong')  # 메서드 체이닝
# Out:
# 'paullab CTO leegildong'

# %%
암호 = '''  + +-+ -+-  
  ++ -- +-+  
  ++-+ -+ -  
  + ++-+ -+  '''

print(암호)
암호.split('\n')[0]
# Out:
#   + +-+ -+-
#   ++ -- +-+
#   ++-+ -+ -
#   + ++-+ -+
# '  + +-+ -+-  '

# %%
# 지금 이 코드에서는 stip을 할 이유가 없지만 앞 뒤 공백만 제거해야 할 때가 있습니다.
이진수 = 암호.split('\n')[0].strip().replace(' ','').replace('+','1').replace('-','0')
int(이진수, 2)
# Out:
# 106

# %%
chr(106) # 유니코드표에서 숫자를 문자로 출력
ord('j') # 유니코드표에서 문자를 숫자로 출력

# %%
# '010-0000-0000'.split('-').zfill(0)  # error, 앞에서 진행한 split이 list를 반환하기 때문에 zfill을 사용할 수 없습니다.
'010-0000-0000'.split('-').count('0000') # 이건 가능합니다. count는 str에도 있지만 list에도 있어요.
# Out:
# 2

# %%
# 아래 3개는 모두 string 입니다.

a = 10
txt = 'hello world {}'

print('hello wolrd {}'.format(a))
print(f'hello world {a}')
print(r'hello world')
print(txt.format(a))
# Out:
# hello wolrd 10
# hello world 10
# hello world
# hello world 10

# %%
r'hello world' # raw : 날 것의
'hello world'
# Out:
# 'hello world'

# %%
print(r'hello \n world')
# Out:
# hello \n world

# %%
print('hello \n world')
# Out:
# hello
#  world

# %%
규칙테이블 = str.maketrans('le','12')
'paullab CEO leehojun'.translate(규칙테이블) #어떤 규칙을 정하는것
# Out:
# 'pau11ab CEO 122hojun'

# %%
규칙테이블 = str.maketrans('vlo','345')
'weniv hello world'.translate(규칙테이블) #어떤 규칙을 정하는것
# Out:
# 'weni3 he445 w5r4d'

# %%
# 참고만 해주세요
규칙테이블 = str.maketrans('CEO','CTO')
'paullab CEO leehojun'.translate(규칙테이블) #어떤 규칙을 정하는것
# Out:
# 'paullab CTO leehojun'

# %% [markdown]
# * 문자열의 활용

# %%
name = 'Guido van Rossum'
print(name[0])
print(name[1])
print(name[2])
# Out:
# G
# u
# i

# %%
s = '위니브 월드 외각에 살고 있는 생선가게...'
# s[start:stop:step]
s[0:6]
s[:6]

s[4:6] # '월드'
s[7:9] # '외각'
s[s.find('외각'):s.find('외각')+2]

s[-1]
s[:-5]
s[:-1] # 많이 사용. 마지막만 제거
s[-7:-1] # 많이 안씀.

s[::2] # 한칸씩 건너뜀
s[::-1] # 꺼꾸로 출력
# Out:
# '위브월 각 고있 선게.'

# %%
# 문자열 사칙연산
s = 'leehojun'

s+s
s*3
# s/s   # error 
# s//s  # error
# s-s   # error

# %%
l = [[[]*3]*3]*2

# %%
l
# Out:
# [[[], [], []], [[], [], []]]

# %%
l[0][0] = 100
l
# Out:
# [[100, [], []], [100, [], []]]

# %% [markdown]
# * 형변환

# %%
print(type(int(3.5)))
print(int(3.5))
print(type(float(3)))
print(float(3))
print(type(str(3)))
print(str(3))
# Out:
# <class 'int'>
# 3
# <class 'float'>
# 3.0
# <class 'str'>
# 3

# %%
x = input('Insert the number.')
y = input('Insert the number.')
print(x + y)
print(type(x))
print(type(y))

# %%
# [10, 20, 15, 17, '철수'] # 감기가 걸려스
l = [10, 20, 15, 17, None]
len(l)
# Out:
# 5

# %%
sum([10, 20, 30, 40], 0)
sum([10, 20, 30, 40], 100)
sum([[1, 2, 3], [4, 5, 6], [7, 8, 9]], [])
# Out:
# 100

# %%
# 숫자 : 0외에 다른 숫자는 다 참
# 문자 : ''외에 다른 문자는 다 참
# 리스트 : []외에 다른 리스트는 다 참
print("bool('test') : ", bool('test'))
print("bool(1) : ", bool(1))
print("bool(0) : ", bool(0))
print("bool(-1) : ", bool(-1))
print("bool(' ') : ", bool(' '))
print("bool('') : ", bool(''))
print("bool(None) : ", bool(None))
# Out:
# bool('test') :  True
# bool(1) :  True
# bool(0) :  False
# bool(-1) :  True
# bool(' ') :  True
# bool('') :  False
# bool(None) :  False

# %%
int()
float()
str()
bool()
list('leehojun')
tuple()

s=[('name','leehojun'),('age',10)]
d=dict(s)
d

set('leehojun')
# Out:
# {'e', 'h', 'j', 'l', 'n', 'o', 'u'}

# %% [markdown]
# ### list(리스트)

# %% [markdown]
# * 순서가 있습니다.
# * 수정이 가능합니다.
# * 리스트 컴프리헨션이 일반 반복보다 속도 우위를 가지고 있습니다.
# * 슬라이싱도 일반 반복보다 속도 우위를 가지고 있습니다.
